# %% [markdown]
# # SONM active deal analyzer

# %% [markdown]
# ## This notebook is to analyze active deals on the SONM platform in real-time.

# %% [markdown]
# ### Import necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### SONM's DWH spits out API information of active deals.  Using Jupyter's magic to run BASH command to save the API data to livedeal.txt

# %%
# !curl -s https://dwh.livenet.sonm.com:15022/DWHServer/GetDeals/ -d '{"status":1}' > livedeal.txt

# %% [markdown]
# ### Open the saved text in Jupyter

# %%
f = open('livedeal.txt','r')

# %% [markdown]
# ### Convert opened file to Pandas dataframe.

# %%
k = f.readlines()

# %%
r = k[0].split(',')

# %%
headposition = []
i = 0
for item in r:
    if 'deal' in item:

        headposition.append(i)
    i = i+1

# %%
testlist = []
for i in range(len(headposition)):
    if headposition[i]>0:
        #print(headposition[i-1], headposition[i])
        #print(r[headposition[i-1] : headposition[i]])
        testlist.append(r[headposition[i-1] : headposition[i]])

# %%
df = pd.DataFrame(testlist)

# %%
df.head()
# Out:
#                                0                             1     2  3   \
# 0  {"deals":[{"deal":{"id":"4695"   "benchmarks":{"values":[104  1062  4
# 1            {"deal":{"id":"3458"  "benchmarks":{"values":[1002   538  8
# 2            {"deal":{"id":"3457"  "benchmarks":{"values":[1004   513  6
# 3            {"deal":{"id":"4641"   "benchmarks":{"values":[286  1079  2
# 4            {"deal":{"id":"4652"   "benchmarks":{"values":[102   778  2
#
#           4         5        6        7  8            9   ...           21  \
# 0  512000000  67108864  1000000  1000000  1   8512339968  ...   "status":1
# 1  256000000  67108864  1000000  1000000  0            0  ...   "status":1
# 2  256000000  67108864  1000000  1000000  0            0  ...   "status":1
# 3  256000000  67108864  1000000  1000000  1   4232052736  ...   "status":1
# 4  256000000  67108864  1000000  1000000  1  11720982528  ...   "status":1
#
#                                       22                                   23  \
# 0  "blockedBalance":"503932480391535840"  "totalPayout":"5224040379763324493"
# 1    "blockedBalance":"1776104355885276"   "totalPayout":"516573758776998019"
# 2    "blockedBalance":"1776104355885276"   "totalPayout":"516578225402296796"
# 3  "blockedBalance":"215600976558482601"  "totalPayout":"5222256751517538479"
# 4  "blockedBalance":"385071439355627448"  "totalPayout":"8830736440951703012"
#
#                                      24            25                    26  \
# 0  "lastBillTS":"2018-08-22T00:08:19Z"}  "netflags":2  "askIdentityLevel":1
# 1  "lastBillTS":"2018-08-22T00:08:16Z"}  "netflags":2  "askIdentityLevel":1
# 2  "lastBillTS":"2018-08-22T00:07:52Z"}  "netflags":2  "askIdentityLevel":1
# 3  "lastBillTS":"2018-08-22T00:07:40Z"}  "netflags":2  "askIdentityLevel":1
# 4  "lastBillTS":"2018-08-22T00:05:49Z"}  "netflags":2  "askIdentityLevel":1
#
#                      27                             28  \
# 0  "bidIdentityLevel":1  "supplierCertificates":"W10="
# 1  "bidIdentityLevel":1  "supplierCertificates":"W10="
# 2  "bidIdentityLevel":1  "supplierCertificates":"W10="
# 3  "bidIdentityLevel":1  "supplierCertificates":"W10="
# 4  "bidIdentityLevel":1  "supplierCertificates":"W10="
#
#                                                   29    30
# 0  "consumerCertificates":"W3sib3duZXJJRCI6IjB4ND...  None
# 1  "consumerCertificates":"W3sib3duZXJJRCI6IjB4MT...  None
# 2  "consumerCertificates":"W3sib3duZXJJRCI6IjB4MT...  None
# 3  "consumerCertificates":"W3sib3duZXJJRCI6IjB4MT...  None
# 4  "consumerCertificates":"W3sib3duZXJJRCI6IjB4MT...  None
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### The 14 column contains consumer ID.  First clean this colum.

# %%
df[14]
# Out:
# 0     "consumerID":"0x417c92FbD944b125A578848DE44a4F...
# 1     "consumerID":"0x18CB84498d67635F14BA20A7A5DD9F...
# 2     "consumerID":"0x18CB84498d67635F14BA20A7A5DD9F...
# 3     "consumerID":"0x18CB84498d67635F14BA20A7A5DD9F...
# 4     "consumerID":"0x18CB84498d67635F14BA20A7A5DD9F...
# 5     "consumerID":"0x18CB84498d67635F14BA20A7A5DD9F...
# 6     "consumerID":"0x49f6C95B97C209F814c5b3B13428E9...
# 7     "consumerID":"0x18CB84498d67635F14BA20A7A5DD9F...
# 8     "consumerID":"0x18CB84498d67635F14BA20A7A5DD9F...
# 9     "consumerID":"0x18CB84498d67635F14BA20A7A5DD9F...
# 10    "consumerID":"0x417c92FbD944b125A578848DE44a4F...
# 11    "consumerID":"0xB4214d064518eed303D966F9ca0Fc6...
# 12    "consumerID":"0x18CB84498d67635F14BA20A7A5DD9F...
# 13    "consumerID":"0xEe7Ff0a44C62209aa7dAa450F67341...
# 14    "consumerID":"0x49f6C95B97C209F814c5b3B13428E9...
# 15    "consumerID":"0x417c92FbD944b125A578848DE44a4F...
# 16    "consumerID":"0x18CB84498d67635F14BA20A7A5DD9F...
# 17    "consumerID":"0x18CB84498d67635F14BA20A7A5DD9F...
# 18    "consumerID":"0x18CB84498d67635F14BA20A7A5DD9F...
# 19    "consumerID":"0x18CB84498d67635F14BA20A7A5DD9F...
# 20    "consumerID":"0x18CB84498d67635F14BA20A7A5DD9F...
# 21    "consumerID":"0xF044524c6A30bC7559DEa1CB21fA11...
# 22    "consumerID":"0x18CB84498d67635F14BA20A7A5DD9F...
# 23    "consumerID":"0x18CB84498d67635F14BA20A7A5DD9F...
# 24    "consumerID":"0xAAA932d77935EE3d8E0Ba1d464CFDA...
# 25    "consumerID":"0xc620838fcaec0e5559aa111f77FC60...
# 26    "consumerID":"0x6f74D76F4c4b80A61598bdED7Fca2f...
# 27    "consumerID":"0xe7517190DB97Ea55E985abdA33745A...
# 28    "consumerID":"0x49f6C95B97C209F814c5b3B13428E9...
# Name: 14, dtype: object

# %% [markdown]
# ### Make a little funtion to trim unnecessary charactors

# %%
def Supplier_ID_conversion(content):
    return content[14:-1]

# %% [markdown]
# ###  And applyt to pandas data frame.  New column called consumer_ID is generated.

# %%
df['consumer_ID'] = df[14].apply(Supplier_ID_conversion)

# %%
df.head()
# Out:
#                                 0                             1     2  3  \
# 0  {"deals":[{"deal":{"id":"4695"   "benchmarks":{"values":[104  1062  4
# 1            {"deal":{"id":"3458"  "benchmarks":{"values":[1002   538  8
# 2            {"deal":{"id":"3457"  "benchmarks":{"values":[1004   513  6
# 3            {"deal":{"id":"4641"   "benchmarks":{"values":[286  1079  2
# 4            {"deal":{"id":"4652"   "benchmarks":{"values":[102   778  2
#
#            4         5        6        7  8            9  \
# 0  512000000  67108864  1000000  1000000  1   8512339968
# 1  256000000  67108864  1000000  1000000  0            0
# 2  256000000  67108864  1000000  1000000  0            0
# 3  256000000  67108864  1000000  1000000  1   4232052736
# 4  256000000  67108864  1000000  1000000  1  11720982528
#
#                       ...                      \
# 0                     ...
# 1                     ...
# 2                     ...
# 3                     ...
# 4                     ...
#
#                                       22                                   23  \
# 0  "blockedBalance":"503932480391535840"  "totalPayout":"5224040379763324493"
# 1    "blockedBalance":"1776104355885276"   "totalPayout":"516573758776998019"
# 2    "blockedBalance":"1776104355885276"   "totalPayout":"516578225402296796"
# 3  "blockedBalance":"215600976558482601"  "totalPayout":"5222256751517538479"
# 4  "blockedBalance":"385071439355627448"  "totalPayout":"8830736440951703012"
#
#                                      24            25                    26  \
# 0  "lastBillTS":"2018-08-22T00:08:19Z"}  "netflags":2  "askIdentityLevel":1
# 1  "lastBillTS":"2018-08-22T00:08:16Z"}  "netflags":2  "askIdentityLevel":1
# 2  "lastBillTS":"2018-08-22T00:07:52Z"}  "netflags":2  "askIdentityLevel":1
# 3  "lastBillTS":"2018-08-22T00:07:40Z"}  "netflags":2  "askIdentityLevel":1
# 4  "lastBillTS":"2018-08-22T00:05:49Z"}  "netflags":2  "askIdentityLevel":1
#
#                      27                             28  \
# 0  "bidIdentityLevel":1  "supplierCertificates":"W10="
# 1  "bidIdentityLevel":1  "supplierCertificates":"W10="
# 2  "bidIdentityLevel":1  "supplierCertificates":"W10="
# 3  "bidIdentityLevel":1  "supplierCertificates":"W10="
# 4  "bidIdentityLevel":1  "supplierCertificates":"W10="
#
#                                                   29    30  \
# 0  "consumerCertificates":"W3sib3duZXJJRCI6IjB4ND...  None
# 1  "consumerCertificates":"W3sib3duZXJJRCI6IjB4MT...  None
# 2  "consumerCertificates":"W3sib3duZXJJRCI6IjB4MT...  None
# 3  "consumerCertificates":"W3sib3duZXJJRCI6IjB4MT...  None
# 4  "consumerCertificates":"W3sib3duZXJJRCI6IjB4MT...  None
#
#                                   consumer_ID
# 0  0x417c92FbD944b125A578848DE44a4FD9132E0911
# 1  0x18CB84498d67635F14BA20A7A5DD9F8254bA5ecb
# 2  0x18CB84498d67635F14BA20A7A5DD9F8254bA5ecb
# 3  0x18CB84498d67635F14BA20A7A5DD9F8254bA5ecb
# 4  0x18CB84498d67635F14BA20A7A5DD9F8254bA5ecb
#
# [5 rows x 32 columns]

# %% [markdown]
# ## supplier

# %% [markdown]
# ###  Same trick for the supplier ID.  The 13 column contains supplier ID information.  Clean with the same function.

# %%
df[13]
# Out:
# 0     "supplierID":"0x2f1B94E3813d66967a478031889F23...
# 1     "supplierID":"0x7Cc1C96E6c20D6265531196d9ca2b3...
# 2     "supplierID":"0x8546601F9b4AcF1dc99C72cc48ED24...
# 3     "supplierID":"0x730F19B7FA079EBfDc7360066ec593...
# 4     "supplierID":"0x47012859fC5cB44d6106D54ff77580...
# 5     "supplierID":"0xaE7DB91DeC00E3Be062C7dC3328859...
# 6     "supplierID":"0xAe4fD4581D82C615105c798c73d1C3...
# 7     "supplierID":"0xd8B606a3D19C53E6Eea84ca5738D7D...
# 8     "supplierID":"0x70eC78FAF2CcD3fA3fe9567Fa5B835...
# 9     "supplierID":"0x672Ee945a55327328472B1a0243729...
# 10    "supplierID":"0x734C2a165e57496169aAAEA6E22aE7...
# 11    "supplierID":"0x844cae5EADD22CaE667F37388D788f...
# 12    "supplierID":"0x8546601F9b4AcF1dc99C72cc48ED24...
# 13    "supplierID":"0x825FfDAB7d275dBAC844eFc36d5E8c...
# 14    "supplierID":"0x8546601F9b4AcF1dc99C72cc48ED24...
# 15    "supplierID":"0xC1bf17F560FA5BF79aF72B4314d147...
# 16    "supplierID":"0x7Cc1C96E6c20D6265531196d9ca2b3...
# 17    "supplierID":"0x7E74e1034bD9270482Fd286F03Cf7F...
# 18    "supplierID":"0x37d7Ae51C3421474709331898B278D...
# 19    "supplierID":"0x26200241593722FA17DE5722Ed66d8...
# 20    "supplierID":"0x91E0fA215FEc1F7D905f59F7FE03F9...
# 21    "supplierID":"0xc364C71bAFAA85671C4d45E5Cf61bf...
# 22    "supplierID":"0x91E0fA215FEc1F7D905f59F7FE03F9...
# 23    "supplierID":"0x7Cc1C96E6c20D6265531196d9ca2b3...
# 24    "supplierID":"0x1E575FB7dD8b28CEcAD9065A7aFD1a...
# 25    "supplierID":"0x323FB5f356088ae979F12f27f94013...
# 26    "supplierID":"0xd87e862c34C5FEE08db543D851089a...
# 27    "supplierID":"0xe8D423ca11ED809565BFA247d974d6...
# 28    "supplierID":"0xC3C8b2915f62956066eD5C8719814e...
# Name: 13, dtype: object

# %%
df['supplier_ID'] = df[13].apply(Supplier_ID_conversion)

# %% [markdown]
# ### Price

# %% [markdown]
# ### Price value is shown as USD/s, so conver it to USD/h

# %%
unit = 10.0**18.0

# %% [markdown]
# 4830442500000/unit * 60 *60

# %%
def Price_conversion(content):
    if 'price' in content:
        return float(content[9:-1])/unit * 60 *60
    if 'duration' in content:
        return float(content[11:-1])/unit * 60 * 60

# %%
df['price_USD/h'] = df[18].apply(Price_conversion)

# %% [markdown]
# ###  ETH has rate

# %% [markdown]
# ### The 10 column contains Ethash value.  Clean and convert to Mh/s.

# %%
df[10]
# Out:
# 0      30105000
# 1             0
# 2             0
# 3      12220000
# 4      22179000
# 5             0
# 6             0
# 7     159643000
# 8     129860000
# 9     186411000
# 10     19778000
# 11            0
# 12            0
# 13            0
# 14            0
# 15     59117000
# 16            0
# 17     64894000
# 18     85636000
# 19    219539000
# 20            0
# 21            0
# 22            0
# 23            0
# 24     21959000
# 25            0
# 26            0
# 27            0
# 28            0
# Name: 10, dtype: object

# %%
float(df[10][0])/1000000
# Out:
# 30.105

# %%
def Ethash_conversion(content):
    return float(content)/1000000

# %%
Ethash_conversion(df[10][0])
# Out:
# 30.105

# %%
df['Ethash'] = df[10].apply(Ethash_conversion)

# %%
df.head()
# Out:
#                                 0                             1     2  3  \
# 0  {"deals":[{"deal":{"id":"4695"   "benchmarks":{"values":[104  1062  4
# 1            {"deal":{"id":"3458"  "benchmarks":{"values":[1002   538  8
# 2            {"deal":{"id":"3457"  "benchmarks":{"values":[1004   513  6
# 3            {"deal":{"id":"4641"   "benchmarks":{"values":[286  1079  2
# 4            {"deal":{"id":"4652"   "benchmarks":{"values":[102   778  2
#
#            4         5        6        7  8            9   ...    \
# 0  512000000  67108864  1000000  1000000  1   8512339968   ...
# 1  256000000  67108864  1000000  1000000  0            0   ...
# 2  256000000  67108864  1000000  1000000  0            0   ...
# 3  256000000  67108864  1000000  1000000  1   4232052736   ...
# 4  256000000  67108864  1000000  1000000  1  11720982528   ...
#
#                      26                    27                             28  \
# 0  "askIdentityLevel":1  "bidIdentityLevel":1  "supplierCertificates":"W10="
# 1  "askIdentityLevel":1  "bidIdentityLevel":1  "supplierCertificates":"W10="
# 2  "askIdentityLevel":1  "bidIdentityLevel":1  "supplierCertificates":"W10="
# 3  "askIdentityLevel":1  "bidIdentityLevel":1  "supplierCertificates":"W10="
# 4  "askIdentityLevel":1  "bidIdentityLevel":1  "supplierCertificates":"W10="
#
#                                                   29    30  \
# 0  "consumerCertificates":"W3sib3duZXJJRCI6IjB4ND...  None
# 1  "consumerCertificates":"W3sib3duZXJJRCI6IjB4MT...  None
# 2  "consumerCertificates":"W3sib3duZXJJRCI6IjB4MT...  None
# 3  "consumerCertificates":"W3sib3duZXJJRCI6IjB4MT...  None
# 4  "consumerCertificates":"W3sib3duZXJJRCI6IjB4MT...  None
#
#                                   consumer_ID  \
# 0  0x417c92FbD944b125A578848DE44a4FD9132E0911
# 1  0x18CB84498d67635F14BA20A7A5DD9F8254bA5ecb
# 2  0x18CB84498d67635F14BA20A7A5DD9F8254bA5ecb
# 3  0x18CB84498d67635F14BA20A7A5DD9F8254bA5ecb
# 4  0x18CB84498d67635F14BA20A7A5DD9F8254bA5ecb
#
#                                   supplier_ID     price price_USD/h  Ethash
# 0  0x2f1B94E3813d66967a478031889F230D805130Ec  0.026753    0.026753  30.105
# 1  0x7Cc1C96E6c20D6265531196d9ca2b3199fF8Ef9E  0.000100    0.000100   0.000
# 2  0x8546601F9b4AcF1dc99C72cc48ED243d119cca95  0.000100    0.000100   0.000
# 3  0x730F19B7FA079EBfDc7360066ec593e4Bdd46Bf2  0.011386    0.011386  12.220
# 4  0x47012859fC5cB44d6106D54ff77580c85C380ecc  0.020609    0.020609  22.179
#
# [5 rows x 36 columns]

# %% [markdown]
# # Run statistics for suppliers

# %%
df.groupby('supplier_ID').describe()['Ethash']
# Out:
#                                             count     mean  std      min  \
# supplier_ID
# 0x1E575FB7dD8b28CEcAD9065A7aFD1aC6c2fBA797    1.0   21.959  NaN   21.959
# 0x26200241593722FA17DE5722Ed66d8830dc58C6D    1.0  219.539  NaN  219.539
# 0x2f1B94E3813d66967a478031889F230D805130Ec    1.0   30.105  NaN   30.105
# 0x323FB5f356088ae979F12f27f94013e449BC62df    1.0    0.000  NaN    0.000
# 0x37d7Ae51C3421474709331898B278D8bAB66eCac    1.0   85.636  NaN   85.636
# 0x47012859fC5cB44d6106D54ff77580c85C380ecc    1.0   22.179  NaN   22.179
# 0x672Ee945a55327328472B1a02437293945157f4C    1.0  186.411  NaN  186.411
# 0x70eC78FAF2CcD3fA3fe9567Fa5B8354Faa4e9457    1.0  129.860  NaN  129.860
# 0x730F19B7FA079EBfDc7360066ec593e4Bdd46Bf2    1.0   12.220  NaN   12.220
# 0x734C2a165e57496169aAAEA6E22aE763fF8d7654    1.0   19.778  NaN   19.778
# 0x7Cc1C96E6c20D6265531196d9ca2b3199fF8Ef9E    3.0    0.000  0.0    0.000
# 0x7E74e1034bD9270482Fd286F03Cf7Fa26Bb99805    1.0   64.894  NaN   64.894
# 0x825FfDAB7d275dBAC844eFc36d5E8ce632d8E7A0    1.0    0.000  NaN    0.000
# 0x844cae5EADD22CaE667F37388D788f79BDd97e62    1.0    0.000  NaN    0.000
# 0x8546601F9b4AcF1dc99C72cc48ED243d119cca95    3.0    0.000  0.0    0.000
# 0x91E0fA215FEc1F7D905f59F7FE03F9EF5090A8A8    2.0    0.000  0.0    0.000
# 0xAe4fD4581D82C615105c798c73d1C33403d86ACB    1.0    0.000  NaN    0.000
# 0xC1bf17F560FA5BF79aF72B4314d14706b90ad2cE    1.0   59.117  NaN   59.117
# 0xC3C8b2915f62956066eD5C8719814e276A7B8C00    1.0    0.000  NaN    0.000
# 0xaE7DB91DeC00E3Be062C7dC33288597DF023e0d6    1.0    0.000  NaN    0.000
# 0xc364C71bAFAA85671C4d45E5Cf61bf19E0225AEb    1.0    0.000  NaN    0.000
# 0xd87e862c34C5FEE08db543D851089a59589438d7    1.0    0.000  NaN    0.000
# 0xd8B606a3D19C53E6Eea84ca5738D7D7d2c0eeb5f    1.0  159.643  NaN  159.643
# 0xe8D423ca11ED809565BFA247d974d6EB42eB2DBb    1.0    0.000  NaN    0.000
#
#                                                 25%      50%      75%      max
# supplier_ID
# 0x1E575FB7dD8b28CEcAD9065A7aFD1aC6c2fBA797   21.959   21.959   21.959   21.959
# 0x26200241593722FA17DE5722Ed66d8830dc58C6D  219.539  219.539  219.539  219.539
# 0x2f1B94E3813d66967a478031889F230D805130Ec   30.105   30.105   30.105   30.105
# 0x323FB5f356088ae979F12f27f94013e449BC62df    0.000    0.000    0.000    0.000
# 0x37d7Ae51C3421474709331898B278D8bAB66eCac   85.636   85.636   85.636   85.636
# 0x47012859fC5cB44d6106D54ff77580c85C380ecc   22.179   22.179   22.179   22.179
# 0x672Ee945a55327328472B1a02437293945157f4C  186.411  186.411  186.411  186.411
# 0x70eC78FAF2CcD3fA3fe9567Fa5B8354Faa4e9457  129.860  129.860  129.860  129.860
# 0x730F19B7FA079EBfDc7360066ec593e4Bdd46Bf2   12.220   12.220   12.220   12.220
# 0x734C2a165e57496169aAAEA6E22aE763fF8d7654   19.778   19.778   19.778   19.778
# 0x7Cc1C96E6c20D6265531196d9ca2b3199fF8Ef9E    0.000    0.000    0.000    0.000
# 0x7E74e1034bD9270482Fd286F03Cf7Fa26Bb99805   64.894   64.894   64.894   64.894
# 0x825FfDAB7d275dBAC844eFc36d5E8ce632d8E7A0    0.000    0.000    0.000    0.000
# 0x844cae5EADD22CaE667F37388D788f79BDd97e62    0.000    0.000    0.000    0.000
# 0x8546601F9b4AcF1dc99C72cc48ED243d119cca95    0.000    0.000    0.000    0.000
# 0x91E0fA215FEc1F7D905f59F7FE03F9EF5090A8A8    0.000    0.000    0.000    0.000
# 0xAe4fD4581D82C615105c798c73d1C33403d86ACB    0.000    0.000    0.000    0.000
# 0xC1bf17F560FA5BF79aF72B4314d14706b90ad2cE   59.117   59.117   59.117   59.117
# 0xC3C8b2915f62956066eD5C8719814e276A7B8C00    0.000    0.000    0.000    0.000
# 0xaE7DB91DeC00E3Be062C7dC33288597DF023e0d6    0.000    0.000    0.000    0.000
# 0xc364C71bAFAA85671C4d45E5Cf61bf19E0225AEb    0.000    0.000    0.000    0.000
# 0xd87e862c34C5FEE08db543D851089a59589438d7    0.000    0.000    0.000    0.000
# 0xd8B606a3D19C53E6Eea84ca5738D7D7d2c0eeb5f  159.643  159.643  159.643  159.643
# 0xe8D423ca11ED809565BFA247d974d6EB42eB2DBb    0.000    0.000    0.000    0.000

# %%
df10 = df.groupby('supplier_ID').describe()['Ethash']

# %%
df10.to_csv('eth.csv')

# %%
df11 = pd.read_csv('eth.csv')

# %%
df11['total_Ethash']= df11['count']*df11['mean']

# %%
df11[['supplier_ID','total_Ethash','count']]
# Out:
#                                    supplier_ID  total_Ethash  count
# 0   0x1E575FB7dD8b28CEcAD9065A7aFD1aC6c2fBA797        21.959    1.0
# 1   0x26200241593722FA17DE5722Ed66d8830dc58C6D       219.539    1.0
# 2   0x2f1B94E3813d66967a478031889F230D805130Ec        30.105    1.0
# 3   0x323FB5f356088ae979F12f27f94013e449BC62df         0.000    1.0
# 4   0x37d7Ae51C3421474709331898B278D8bAB66eCac        85.636    1.0
# 5   0x47012859fC5cB44d6106D54ff77580c85C380ecc        22.179    1.0
# 6   0x672Ee945a55327328472B1a02437293945157f4C       186.411    1.0
# 7   0x70eC78FAF2CcD3fA3fe9567Fa5B8354Faa4e9457       129.860    1.0
# 8   0x730F19B7FA079EBfDc7360066ec593e4Bdd46Bf2        12.220    1.0
# 9   0x734C2a165e57496169aAAEA6E22aE763fF8d7654        19.778    1.0
# 10  0x7Cc1C96E6c20D6265531196d9ca2b3199fF8Ef9E         0.000    3.0
# 11  0x7E74e1034bD9270482Fd286F03Cf7Fa26Bb99805        64.894    1.0
# 12  0x825FfDAB7d275dBAC844eFc36d5E8ce632d8E7A0         0.000    1.0
# 13  0x844cae5EADD22CaE667F37388D788f79BDd97e62         0.000    1.0
# 14  0x8546601F9b4AcF1dc99C72cc48ED243d119cca95         0.000    3.0
# 15  0x91E0fA215FEc1F7D905f59F7FE03F9EF5090A8A8         0.000    2.0
# 16  0xAe4fD4581D82C615105c798c73d1C33403d86ACB         0.000    1.0
# 17  0xC1bf17F560FA5BF79aF72B4314d14706b90ad2cE        59.117    1.0
# 18  0xC3C8b2915f62956066eD5C8719814e276A7B8C00         0.000    1.0
# 19  0xaE7DB91DeC00E3Be062C7dC33288597DF023e0d6         0.000    1.0
# 20  0xc364C71bAFAA85671C4d45E5Cf61bf19E0225AEb         0.000    1.0
# 21  0xd87e862c34C5FEE08db543D851089a59589438d7         0.000    1.0
# 22  0xd8B606a3D19C53E6Eea84ca5738D7D7d2c0eeb5f       159.643    1.0
# 23  0xe8D423ca11ED809565BFA247d974d6EB42eB2DBb         0.000    1.0

# %%
df11[['supplier_ID','total_Ethash','count']].sort_values('total_Ethash', ascending = False)
# Out:
#                                    supplier_ID  total_Ethash  count
# 1   0x26200241593722FA17DE5722Ed66d8830dc58C6D       219.539    1.0
# 6   0x672Ee945a55327328472B1a02437293945157f4C       186.411    1.0
# 22  0xd8B606a3D19C53E6Eea84ca5738D7D7d2c0eeb5f       159.643    1.0
# 7   0x70eC78FAF2CcD3fA3fe9567Fa5B8354Faa4e9457       129.860    1.0
# 4   0x37d7Ae51C3421474709331898B278D8bAB66eCac        85.636    1.0
# 11  0x7E74e1034bD9270482Fd286F03Cf7Fa26Bb99805        64.894    1.0
# 17  0xC1bf17F560FA5BF79aF72B4314d14706b90ad2cE        59.117    1.0
# 2   0x2f1B94E3813d66967a478031889F230D805130Ec        30.105    1.0
# 5   0x47012859fC5cB44d6106D54ff77580c85C380ecc        22.179    1.0
# 0   0x1E575FB7dD8b28CEcAD9065A7aFD1aC6c2fBA797        21.959    1.0
# 9   0x734C2a165e57496169aAAEA6E22aE763fF8d7654        19.778    1.0
# 8   0x730F19B7FA079EBfDc7360066ec593e4Bdd46Bf2        12.220    1.0
# 21  0xd87e862c34C5FEE08db543D851089a59589438d7         0.000    1.0
# 20  0xc364C71bAFAA85671C4d45E5Cf61bf19E0225AEb         0.000    1.0
# 19  0xaE7DB91DeC00E3Be062C7dC33288597DF023e0d6         0.000    1.0
# 18  0xC3C8b2915f62956066eD5C8719814e276A7B8C00         0.000    1.0
# 12  0x825FfDAB7d275dBAC844eFc36d5E8ce632d8E7A0         0.000    1.0
# 16  0xAe4fD4581D82C615105c798c73d1C33403d86ACB         0.000    1.0
# 15  0x91E0fA215FEc1F7D905f59F7FE03F9EF5090A8A8         0.000    2.0
# 14  0x8546601F9b4AcF1dc99C72cc48ED243d119cca95         0.000    3.0
# 13  0x844cae5EADD22CaE667F37388D788f79BDd97e62         0.000    1.0
# 10  0x7Cc1C96E6c20D6265531196d9ca2b3199fF8Ef9E         0.000    3.0
# 3   0x323FB5f356088ae979F12f27f94013e449BC62df         0.000    1.0
# 23  0xe8D423ca11ED809565BFA247d974d6EB42eB2DBb         0.000    1.0

# %%
df12 = df11[['supplier_ID','total_Ethash','count']].sort_values('total_Ethash', ascending = False)

# %%
df12.to_csv('ethash.csv', index = False)

# %%
df13 = pd.read_csv('ethash.csv')

# %%
df13
# Out:
#                                    supplier_ID  total_Ethash  count
# 0   0x26200241593722FA17DE5722Ed66d8830dc58C6D       219.539    1.0
# 1   0x672Ee945a55327328472B1a02437293945157f4C       186.411    1.0
# 2   0xd8B606a3D19C53E6Eea84ca5738D7D7d2c0eeb5f       159.643    1.0
# 3   0x70eC78FAF2CcD3fA3fe9567Fa5B8354Faa4e9457       129.860    1.0
# 4   0x37d7Ae51C3421474709331898B278D8bAB66eCac        85.636    1.0
# 5   0x7E74e1034bD9270482Fd286F03Cf7Fa26Bb99805        64.894    1.0
# 6   0xC1bf17F560FA5BF79aF72B4314d14706b90ad2cE        59.117    1.0
# 7   0x2f1B94E3813d66967a478031889F230D805130Ec        30.105    1.0
# 8   0x47012859fC5cB44d6106D54ff77580c85C380ecc        22.179    1.0
# 9   0x1E575FB7dD8b28CEcAD9065A7aFD1aC6c2fBA797        21.959    1.0
# 10  0x734C2a165e57496169aAAEA6E22aE763fF8d7654        19.778    1.0
# 11  0x730F19B7FA079EBfDc7360066ec593e4Bdd46Bf2        12.220    1.0
# 12  0xd87e862c34C5FEE08db543D851089a59589438d7         0.000    1.0
# 13  0xc364C71bAFAA85671C4d45E5Cf61bf19E0225AEb         0.000    1.0
# 14  0xaE7DB91DeC00E3Be062C7dC33288597DF023e0d6         0.000    1.0
# 15  0xC3C8b2915f62956066eD5C8719814e276A7B8C00         0.000    1.0
# 16  0x825FfDAB7d275dBAC844eFc36d5E8ce632d8E7A0         0.000    1.0
# 17  0xAe4fD4581D82C615105c798c73d1C33403d86ACB         0.000    1.0
# 18  0x91E0fA215FEc1F7D905f59F7FE03F9EF5090A8A8         0.000    2.0
# 19  0x8546601F9b4AcF1dc99C72cc48ED243d119cca95         0.000    3.0
# 20  0x844cae5EADD22CaE667F37388D788f79BDd97e62         0.000    1.0
# 21  0x7Cc1C96E6c20D6265531196d9ca2b3199fF8Ef9E         0.000    3.0
# 22  0x323FB5f356088ae979F12f27f94013e449BC62df         0.000    1.0
# 23  0xe8D423ca11ED809565BFA247d974d6EB42eB2DBb         0.000    1.0

# %%
df13['total_Ethash'].sum()
# Out:
# 1011.3409999999999

# %%
print('Real-time total Ethash rate of the entire SONM platform is '+ str(df13['total_Ethash'].sum()) +' Mh/s')
# Out:
# Real-time total Ethash rate of the entire SONM platform is 1011.341 Mh/s

# %% [markdown]
# ## supplier's revenue

# %%
df13['supplier_ID'][0]
# Out:
# '0x26200241593722FA17DE5722Ed66d8830dc58C6D'

# %%
df[df.supplier_ID == df13['supplier_ID'][0]]['price_USD/h'].sum()
# Out:
# 0.22599999999999718

# %%
def total_revenue(address):
    return df[df.supplier_ID == address]['price_USD/h'].sum()

# %%
total_revenue(df13['supplier_ID'][0])
# Out:
# 0.22599999999999718

# %%
df13['total_revenue_USD/h'] = df13['supplier_ID'].apply(total_revenue)

# %%
df13.dtypes
# Out:
# supplier_ID             object
# total_Ethash           float64
# count                  float64
# total_revenue_USD/h    float64
# dtype: object

# %%
df13['total_revenue_USD/d'] = df13['total_revenue_USD/h'] *24

# %%
df13['revenue_USD/d'] = df13['total_revenue_USD/d'].map('${:,.2f}'.format)

# %%
df13[['supplier_ID','total_Ethash','count','revenue_USD/d']]
# Out:
#                                    supplier_ID  total_Ethash  count  \
# 0   0x26200241593722FA17DE5722Ed66d8830dc58C6D       219.539    1.0
# 1   0x672Ee945a55327328472B1a02437293945157f4C       186.411    1.0
# 2   0xd8B606a3D19C53E6Eea84ca5738D7D7d2c0eeb5f       159.643    1.0
# 3   0x70eC78FAF2CcD3fA3fe9567Fa5B8354Faa4e9457       129.860    1.0
# 4   0x37d7Ae51C3421474709331898B278D8bAB66eCac        85.636    1.0
# 5   0x7E74e1034bD9270482Fd286F03Cf7Fa26Bb99805        64.894    1.0
# 6   0xC1bf17F560FA5BF79aF72B4314d14706b90ad2cE        59.117    1.0
# 7   0x2f1B94E3813d66967a478031889F230D805130Ec        30.105    1.0
# 8   0x47012859fC5cB44d6106D54ff77580c85C380ecc        22.179    1.0
# 9   0x1E575FB7dD8b28CEcAD9065A7aFD1aC6c2fBA797        21.959    1.0
# 10  0x734C2a165e57496169aAAEA6E22aE763fF8d7654        19.778    1.0
# 11  0x730F19B7FA079EBfDc7360066ec593e4Bdd46Bf2        12.220    1.0
# 12  0xd87e862c34C5FEE08db543D851089a59589438d7         0.000    1.0
# 13  0xc364C71bAFAA85671C4d45E5Cf61bf19E0225AEb         0.000    1.0
# 14  0xaE7DB91DeC00E3Be062C7dC33288597DF023e0d6         0.000    1.0
# 15  0xC3C8b2915f62956066eD5C8719814e276A7B8C00         0.000    1.0
# 16  0x825FfDAB7d275dBAC844eFc36d5E8ce632d8E7A0         0.000    1.0
# 17  0xAe4fD4581D82C615105c798c73d1C33403d86ACB         0.000    1.0
# 18  0x91E0fA215FEc1F7D905f59F7FE03F9EF5090A8A8         0.000    2.0
# 19  0x8546601F9b4AcF1dc99C72cc48ED243d119cca95         0.000    3.0
# 20  0x844cae5EADD22CaE667F37388D788f79BDd97e62         0.000    1.0
# 21  0x7Cc1C96E6c20D6265531196d9ca2b3199fF8Ef9E         0.000    3.0
# 22  0x323FB5f356088ae979F12f27f94013e449BC62df         0.000    1.0
# 23  0xe8D423ca11ED809565BFA247d974d6EB42eB2DBb         0.000    1.0
#
#    revenue_USD/d
# 0          $5.42
# 1          $4.47
# 2          $3.89
# 3          $3.39
# 4          $1.92
# 5          $1.45
# 6          $1.26
# 7          $0.64
# 8          $0.49
# 9          $0.48
# 10         $0.42
# 11         $0.27
# 12         $0.00
# 13         $0.00
# 14         $0.01
# 15         $0.00
# 16         $0.00
# 17         $0.00
# 18         $0.00
# 19         $0.00
# 20         $0.24
# 21         $0.00
# 22         $0.00
# 23         $0.00

# %% [markdown]
# # Run the same statistics for consumers

# %%
df.groupby('consumer_ID').describe()['Ethash']
# Out:
#                                             count       mean        std  \
# consumer_ID
# 0x18CB84498d67635F14BA20A7A5DD9F8254bA5ecb   16.0  55.023875  77.045399
# 0x417c92FbD944b125A578848DE44a4FD9132E0911    3.0  36.333333  20.395669
# 0x49f6C95B97C209F814c5b3B13428E91686a1FEd9    3.0   0.000000   0.000000
# 0x6f74D76F4c4b80A61598bdED7Fca2f660CA742Ce    1.0   0.000000        NaN
# 0xAAA932d77935EE3d8E0Ba1d464CFDA4E56566A01    1.0  21.959000        NaN
# 0xB4214d064518eed303D966F9ca0Fc62Ac8dF20EE    1.0   0.000000        NaN
# 0xEe7Ff0a44C62209aa7dAa450F673415bC90bFC11    1.0   0.000000        NaN
# 0xF044524c6A30bC7559DEa1CB21fA11b1f5817833    1.0   0.000000        NaN
# 0xc620838fcaec0e5559aa111f77FC6016650c63E4    1.0   0.000000        NaN
# 0xe7517190DB97Ea55E985abdA33745AfC41a83592    1.0   0.000000        NaN
#
#                                                min      25%     50%     75%  \
# consumer_ID
# 0x18CB84498d67635F14BA20A7A5DD9F8254bA5ecb   0.000   0.0000   6.110  96.692
# 0x417c92FbD944b125A578848DE44a4FD9132E0911  19.778  24.9415  30.105  44.611
# 0x49f6C95B97C209F814c5b3B13428E91686a1FEd9   0.000   0.0000   0.000   0.000
# 0x6f74D76F4c4b80A61598bdED7Fca2f660CA742Ce   0.000   0.0000   0.000   0.000
# 0xAAA932d77935EE3d8E0Ba1d464CFDA4E56566A01  21.959  21.9590  21.959  21.959
# 0xB4214d064518eed303D966F9ca0Fc62Ac8dF20EE   0.000   0.0000   0.000   0.000
# 0xEe7Ff0a44C62209aa7dAa450F673415bC90bFC11   0.000   0.0000   0.000   0.000
# 0xF044524c6A30bC7559DEa1CB21fA11b1f5817833   0.000   0.0000   0.000   0.000
# 0xc620838fcaec0e5559aa111f77FC6016650c63E4   0.000   0.0000   0.000   0.000
# 0xe7517190DB97Ea55E985abdA33745AfC41a83592   0.000   0.0000   0.000   0.000
#
#                                                 max
# consumer_ID
# 0x18CB84498d67635F14BA20A7A5DD9F8254bA5ecb  219.539
# 0x417c92FbD944b125A578848DE44a4FD9132E0911   59.117
# 0x49f6C95B97C209F814c5b3B13428E91686a1FEd9    0.000
# 0x6f74D76F4c4b80A61598bdED7Fca2f660CA742Ce    0.000
# 0xAAA932d77935EE3d8E0Ba1d464CFDA4E56566A01   21.959
# 0xB4214d064518eed303D966F9ca0Fc62Ac8dF20EE    0.000
# 0xEe7Ff0a44C62209aa7dAa450F673415bC90bFC11    0.000
# 0xF044524c6A30bC7559DEa1CB21fA11b1f5817833    0.000
# 0xc620838fcaec0e5559aa111f77FC6016650c63E4    0.000
# 0xe7517190DB97Ea55E985abdA33745AfC41a83592    0.000

# %%
df10 = df.groupby('consumer_ID').describe()['Ethash']

# %%
df10.to_csv('consumer.csv')

# %%
df11 = pd.read_csv('consumer.csv')

# %%
df11['total_Ethash']= df11['mean']*df11['count']

# %%
df11
# Out:
#                                   consumer_ID  count       mean        std  \
# 0  0x18CB84498d67635F14BA20A7A5DD9F8254bA5ecb   16.0  55.023875  77.045399
# 1  0x417c92FbD944b125A578848DE44a4FD9132E0911    3.0  36.333333  20.395669
# 2  0x49f6C95B97C209F814c5b3B13428E91686a1FEd9    3.0   0.000000   0.000000
# 3  0x6f74D76F4c4b80A61598bdED7Fca2f660CA742Ce    1.0   0.000000        NaN
# 4  0xAAA932d77935EE3d8E0Ba1d464CFDA4E56566A01    1.0  21.959000        NaN
# 5  0xB4214d064518eed303D966F9ca0Fc62Ac8dF20EE    1.0   0.000000        NaN
# 6  0xEe7Ff0a44C62209aa7dAa450F673415bC90bFC11    1.0   0.000000        NaN
# 7  0xF044524c6A30bC7559DEa1CB21fA11b1f5817833    1.0   0.000000        NaN
# 8  0xc620838fcaec0e5559aa111f77FC6016650c63E4    1.0   0.000000        NaN
# 9  0xe7517190DB97Ea55E985abdA33745AfC41a83592    1.0   0.000000        NaN
#
#       min      25%     50%     75%      max  total_Ethash
# 0   0.000   0.0000   6.110  96.692  219.539       880.382
# 1  19.778  24.9415  30.105  44.611   59.117       109.000
# 2   0.000   0.0000   0.000   0.000    0.000         0.000
# 3   0.000   0.0000   0.000   0.000    0.000         0.000
# 4  21.959  21.9590  21.959  21.959   21.959        21.959
# 5   0.000   0.0000   0.000   0.000    0.000         0.000
# 6   0.000   0.0000   0.000   0.000    0.000         0.000
# 7   0.000   0.0000   0.000   0.000    0.000         0.000
# 8   0.000   0.0000   0.000   0.000    0.000         0.000
# 9   0.000   0.0000   0.000   0.000    0.000         0.000

# %%
df11[['consumer_ID', 'total_Ethash', 'count']]
# Out:
#                                   consumer_ID  total_Ethash  count
# 0  0x18CB84498d67635F14BA20A7A5DD9F8254bA5ecb       880.382   16.0
# 1  0x417c92FbD944b125A578848DE44a4FD9132E0911       109.000    3.0
# 2  0x49f6C95B97C209F814c5b3B13428E91686a1FEd9         0.000    3.0
# 3  0x6f74D76F4c4b80A61598bdED7Fca2f660CA742Ce         0.000    1.0
# 4  0xAAA932d77935EE3d8E0Ba1d464CFDA4E56566A01        21.959    1.0
# 5  0xB4214d064518eed303D966F9ca0Fc62Ac8dF20EE         0.000    1.0
# 6  0xEe7Ff0a44C62209aa7dAa450F673415bC90bFC11         0.000    1.0
# 7  0xF044524c6A30bC7559DEa1CB21fA11b1f5817833         0.000    1.0
# 8  0xc620838fcaec0e5559aa111f77FC6016650c63E4         0.000    1.0
# 9  0xe7517190DB97Ea55E985abdA33745AfC41a83592         0.000    1.0

# %% [markdown]
# # Connor's deals

# %%
df[df.consumer_ID == '0x417c92FbD944b125A578848DE44a4FD9132E0911']
# Out:
#                                  0                            1     2  3  \
# 0   {"deals":[{"deal":{"id":"4695"  "benchmarks":{"values":[104  1062  4
# 10            {"deal":{"id":"4700"  "benchmarks":{"values":[108  1113  8
# 15            {"deal":{"id":"4692"  "benchmarks":{"values":[114  1525  4
#
#             4         5        6        7  8           9   ...    \
# 0   512000000  67108864  1000000  1000000  1  8512339968   ...
# 10  512000000  67108864  1000000  1000001  1  6368002048   ...
# 15  512000000  67108864  1000000  1000000  2  8513388544   ...
#
#                       26                    27  \
# 0   "askIdentityLevel":1  "bidIdentityLevel":1
# 10  "askIdentityLevel":1  "bidIdentityLevel":1
# 15  "askIdentityLevel":1  "bidIdentityLevel":1
#
#                                                    28  \
# 0                       "supplierCertificates":"W10="
# 10  "supplierCertificates":"W3sib3duZXJJRCI6IjB4Nk...
# 15  "supplierCertificates":"W3sib3duZXJJRCI6IjB4NT...
#
#                                                    29    30  \
# 0   "consumerCertificates":"W3sib3duZXJJRCI6IjB4ND...  None
# 10  "consumerCertificates":"W3sib3duZXJJRCI6IjB4ND...  None
# 15  "consumerCertificates":"W3sib3duZXJJRCI6IjB4ND...  None
#
#                                    consumer_ID  \
# 0   0x417c92FbD944b125A578848DE44a4FD9132E0911
# 10  0x417c92FbD944b125A578848DE44a4FD9132E0911
# 15  0x417c92FbD944b125A578848DE44a4FD9132E0911
#
#                                    supplier_ID     price price_USD/h  Ethash
# 0   0x2f1B94E3813d66967a478031889F230D805130Ec  0.026753    0.026753  30.105
# 10  0x734C2a165e57496169aAAEA6E22aE763fF8d7654  0.017390    0.017390  19.778
# 15  0xC1bf17F560FA5BF79aF72B4314d14706b90ad2cE  0.052615    0.052615  59.117
#
# [3 rows x 36 columns]

# %%
df12 = df[df.consumer_ID == '0x417c92FbD944b125A578848DE44a4FD9132E0911']

# %%
df12[['consumer_ID', 'supplier_ID', 'price_USD/h', 'Ethash',0]]
# Out:
#                                    consumer_ID  \
# 0   0x417c92FbD944b125A578848DE44a4FD9132E0911
# 10  0x417c92FbD944b125A578848DE44a4FD9132E0911
# 15  0x417c92FbD944b125A578848DE44a4FD9132E0911
#
#                                    supplier_ID  price_USD/h  Ethash  \
# 0   0x2f1B94E3813d66967a478031889F230D805130Ec     0.026753  30.105
# 10  0x734C2a165e57496169aAAEA6E22aE763fF8d7654     0.017390  19.778
# 15  0xC1bf17F560FA5BF79aF72B4314d14706b90ad2cE     0.052615  59.117
#
#                                  0
# 0   {"deals":[{"deal":{"id":"4695"
# 10            {"deal":{"id":"4700"
# 15            {"deal":{"id":"4692"
